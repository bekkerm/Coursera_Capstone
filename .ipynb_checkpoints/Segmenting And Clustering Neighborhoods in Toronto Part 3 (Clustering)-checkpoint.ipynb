# %% [markdown]
# #### Import libraries

# %%
import pandas as pd
import numpy as np
import requests
import warnings
warnings.filterwarnings('ignore')
import geopy
from geopy.geocoders import Nominatim
import geocoder
g = geocoder.geonames('Toronto, Ontario')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-844b063017ae> in <module>
#       7 from geopy.geocoders import Nominatim
#       8 import geocoder
# ----> 9 g = geocoder.geonames('Toronto, Ontario')
#
# /opt/conda/lib/python3.7/site-packages/geocoder/api.py in geonames(location, **kwargs)
#     536         > hierarchy
#     537     """
# --> 538     return get(location, provider='geonames', **kwargs)
#     539
#     540
#
# /opt/conda/lib/python3.7/site-packages/geocoder/api.py in get(location, **kwargs)
#     196         if method not in options[provider]:
#     197             raise ValueError("Invalid method")
# --> 198     return options[provider][method](location, **kwargs)
#     199
#     200
#
# /opt/conda/lib/python3.7/site-packages/geocoder/base.py in __init__(self, location, **kwargs)
#     378
#     379         # check validity of provider key
# --> 380         provider_key = self._get_api_key(kwargs.pop('key', ''))
#     381
#     382         # point to geocode, as a string or coordinates
#
# /opt/conda/lib/python3.7/site-packages/geocoder/base.py in _get_api_key(cls, key)
#     354         # raise exception if not valid key found
#     355         if not key and cls._KEY_MANDATORY:
# --> 356             raise ValueError('Provide API Key')
#     357
#     358         return key
#
# ValueError: Provide API Key

# %% [markdown]
# #### Set the url to table location and get the content of the page in variable

# %%
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
page = requests.get(url).content

# %% [markdown]
# #### Use the pandas read_html function to read the table. In this case the first table on the page ([0])

# %%
df_raw = pd.read_html(page,header=0)[0]

# %%
df_raw.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront

# %% [markdown]
# #### Let's clean up the dataset according to specifications, filtering and replacing values

# %%
df = df_raw[df_raw['Borough'] != 'Not assigned'] #filter
df.columns = ['PostalCode','Borough','Neighborhood']
df.loc[df['Neighborhood'] == 'Not assigned',['Neighborhood']] = df['Borough'] #replace Neigborhood with Borough if Neigborhood = 'Not assigned'

# %% [markdown]
# #### Group the dataframe and apply the string concatenation

# %%
df = df.groupby(by=['PostalCode','Borough']).agg(lambda x: ', '.join(set(x))).reset_index()

# %% [markdown]
# #### Finally let's show the final frame (103 records with 3 columns)

# %%
df.shape
# Out:
# (103, 3)

# %% [markdown]
# #### We have the dataframe setup, now let's find the longitude and latitude. I'm using the provided csv

# %%
PostalCodes = df['PostalCode'].unique()

# %%
# initialize your variable to None
lat_lng_coords = None

# loop until you get the coordinates
while(lat_lng_coords is None):
  g = geocoder.google('{}, Toronto, Ontario'.format(PostalCodes))
  lat_lng_coords = g.latlng

latitude = lat_lng_coords[0]
longitude = lat_lng_coords[1]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-58-ed15500975ba> in <module>
#       4 # loop until you get the coordinates
#       5 while(lat_lng_coords is None):
# ----> 6   g = geocoder.google('{}, Toronto, Ontario'.format(PostalCodes))
#       7   lat_lng_coords = g.latlng
#       8
#
# /opt/conda/lib/python3.7/site-packages/geocoder/api.py in google(location, **kwargs)
#     230         > elevation
#     231     """
# --> 232     return get(location, provider='google', **kwargs)
#     233
#     234
#
# /opt/conda/lib/python3.7/site-packages/geocoder/api.py in get(location, **kwargs)
#     196         if method not in options[provider]:
#     197             raise ValueError("Invalid method")
# --> 198     return options[provider][method](location, **kwargs)
#     199
#     200
#
# /opt/conda/lib/python3.7/site-packages/geocoder/base.py in __init__(self, location, **kwargs)
#     408
#     409         # query and parse results
# --> 410         self._initialize()
#     411
#     412     def __getitem__(self, key):
#
# /opt/conda/lib/python3.7/site-packages/geocoder/base.py in _initialize(self)
#     455     def _initialize(self):
#     456         # query URL and get valid JSON (also stored in self.json)
# --> 457         json_response = self._connect()
#     458
#     459         # catch errors
#
# /opt/conda/lib/python3.7/site-packages/geocoder/base.py in _connect(self)
#     482                 headers=self.headers,
#     483                 timeout=self.timeout,
# --> 484                 proxies=self.proxies
#     485             )
#     486
#
# /opt/conda/lib/python3.7/site-packages/geocoder/google.py in rate_limited_get(self, *args, **kwargs)
#     267             return self.rate_limited_get_for_work(*args, **kwargs)
#     268         else:
# --> 269             return self.rate_limited_get_for_dev(*args, **kwargs)
#     270
#     271     @ratelim.greedy(2500, 60 * 60 * 24)
#
# </opt/conda/lib/python3.7/site-packages/decorator.py:decorator-gen-128> in rate_limited_get_for_dev(self, *args, **kwargs)
#
# /opt/conda/lib/python3.7/site-packages/ratelim/__init__.py in wrapped_f(self, f, *args, **kwargs)
#      31             time_delta = int(time_delta.total_seconds()) + 1
#      32             if time_delta <= self.__time_interval:
# ---> 33                 time.sleep(self.__time_interval - time_delta + 1)
#      34                 self.__numcalls = 0
#      35                 self.__last_reset = datetime.datetime.now()
#
# KeyboardInterrupt:

# %%
df['Latitude'] = geocoder.google('{}, Toronto, Ontario'.format())
# Out:
# array(['M1B', 'M1C', 'M1E', 'M1G', 'M1H', 'M1J', 'M1K', 'M1L', 'M1M',
#        'M1N', 'M1P', 'M1R', 'M1S', 'M1T', 'M1V', 'M1W', 'M1X', 'M2H',
#        'M2J', 'M2K', 'M2L', 'M2M', 'M2N', 'M2P', 'M2R', 'M3A', 'M3B',
#        'M3C', 'M3H', 'M3J', 'M3K', 'M3L', 'M3M', 'M3N', 'M4A', 'M4B',
#        'M4C', 'M4E', 'M4G', 'M4H', 'M4J', 'M4K', 'M4L', 'M4M', 'M4N',
#        'M4P', 'M4R', 'M4S', 'M4T', 'M4V', 'M4W', 'M4X', 'M4Y', 'M5A',
#        'M5B', 'M5C', 'M5E', 'M5G', 'M5H', 'M5J', 'M5K', 'M5L', 'M5M',
#        'M5N', 'M5P', 'M5R', 'M5S', 'M5T', 'M5V', 'M5W', 'M5X', 'M6A',
#        'M6B', 'M6C', 'M6E', 'M6G', 'M6H', 'M6J', 'M6K', 'M6L', 'M6M',
#        'M6N', 'M6P', 'M6R', 'M6S', 'M7A', 'M7R', 'M7Y', 'M8V', 'M8W',
#        'M8X', 'M8Y', 'M8Z', 'M9A', 'M9B', 'M9C', 'M9L', 'M9M', 'M9N',
#        'M9P', 'M9R', 'M9V', 'M9W'], dtype=object)

# %% [markdown]
# #### We now have the location data per postalcode so now it will be joined together with the Toronto dataframe

# %%
file = 'Geospatial_Coordinates.csv'
df_geo = pd.read_csv(file)
df_geo.rename(columns = {'Postal Code':'PostalCode'}, inplace = True)

# %%
df_toronto = pd.merge(df,df_geo, on='PostalCode',how='left')

# %% [markdown]
# #### This leaves with clean appended dataframe incl lot and long

# %%
df_toronto.head(9)
# Out:
#   PostalCode      Borough                                     Neighborhood  \
# 0        M1B  Scarborough                                   Malvern, Rouge
# 1        M1C  Scarborough           Highland Creek, Rouge Hill, Port Union
# 2        M1E  Scarborough                West Hill, Guildwood, Morningside
# 3        M1G  Scarborough                                           Woburn
# 4        M1H  Scarborough                                        Cedarbrae
# 5        M1J  Scarborough                              Scarborough Village
# 6        M1K  Scarborough      Ionview, Kennedy Park, East Birchmount Park
# 7        M1L  Scarborough                  Golden Mile, Clairlea, Oakridge
# 8        M1M  Scarborough  Cliffside, Cliffcrest, Scarborough Village West
#
#     Latitude  Longitude
# 0  43.806686 -79.194353
# 1  43.784535 -79.160497
# 2  43.763573 -79.188711
# 3  43.770992 -79.216917
# 4  43.773136 -79.239476
# 5  43.744734 -79.239476
# 6  43.727929 -79.262029
# 7  43.711112 -79.284577
# 8  43.716316 -79.239476

# %% [markdown]
# #### we'll define the start zoom location of the folium map with the address and geolocator to get the latitude and longitude

# %%
address = 'Toronto, Ontario'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinates of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinates of Toronto are 43.653963, -79.387207.

# %% [markdown]
# #### Now we plot the areas onto the Toronto map

# %%
# create map of New York using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(df_toronto['Latitude'], df_toronto['Longitude'], df_toronto['Borough'], df_toronto['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### now we have the initial map setup we continue with clustering
